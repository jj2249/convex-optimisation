# %%
import numpy as np
from norm_approximation import *
from data_loader import *
import time
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
a1, b1 = load_npy(1)
a2, b2 = load_npy(2)
a3, b3 = load_npy(3)
a4, b4 = load_npy(4)
a5, b5 = load_npy(5)

# %%
start_time = time.time()
x11, s11 = solve_lone(a5, b5)
time.time() - start_time
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0:  0.0000e+00  2.6645e-14  5e+03  4e+00  2e-14  1e+00
#  1:  2.6085e+02  2.6085e+02  8e+02  7e-01  3e-14  2e-01
#  2:  4.7580e+02  4.7580e+02  3e+02  2e-01  2e-13  7e-02
#  3:  5.3732e+02  5.3732e+02  1e+02  1e-01  2e-13  3e-02
#  4:  5.5553e+02  5.5553e+02  7e+01  6e-02  3e-13  2e-02
#  5:  5.6723e+02  5.6723e+02  3e+01  3e-02  3e-13  7e-03
#  6:  5.7231e+02  5.7231e+02  1e+01  1e-02  4e-13  3e-03
#  7:  5.7454e+02  5.7454e+02  5e+00  4e-03  7e-13  1e-03
#  8:  5.7527e+02  5.7527e+02  2e+00  2e-03  9e-13  6e-04
#  9:  5.7571e+02  5.7571e+02  7e-01  6e-04  2e-12  2e-04
# 10:  5.7582e+02  5.7582e+02  3e-01  2e-04  3e-12  7e-05
# 11:  5.7587e+02  5.7587e+02  1e-01  9e-05  5e-12  2e-05
# 12:  5.7589e+02  5.7589e+02  3e-02  3e-05  5e-12  8e-06
# 13:  5.7590e+02  5.7590e+02  9e-03  7e-06  1e-11  2e-06
# 14:  5.7590e+02  5.7590e+02  3e-03  2e-06  3e-11  7e-07
# 15:  5.7590e+02  5.7590e+02  5e-04  4e-07  2e-11  1e-07
# ...

# %%
start_time = time.time()
x22, s22 = solve_ltwo(a5, b5)
time.time() - start_time
# Out:
# 0.029912948608398438

# %%
start_time = time.time()
x33, s33 = solve_linf(a5, b5)
time.time() - start_time
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0:  3.9568e-17  2.4693e-17  2e+00  4e+00  5e-16  1e+00
#  1:  2.2756e-01  1.3155e-01  8e-01  1e+00  8e-16  2e-01
#  2:  5.3197e-01  4.1931e-01  5e-01  7e-01  3e-15  6e-02
#  3:  5.6791e-01  5.3630e-01  1e-01  2e-01  2e-15  1e-02
#  4:  5.8172e-01  5.6330e-01  6e-02  8e-02  3e-15  2e-03
#  5:  5.9311e-01  5.8563e-01  3e-02  3e-02  5e-15  5e-04
#  6:  5.9793e-01  5.9496e-01  1e-02  1e-02  1e-14  1e-04
#  7:  5.9988e-01  5.9866e-01  4e-03  5e-03  2e-14  3e-05
#  8:  6.0081e-01  6.0033e-01  2e-03  2e-03  4e-14  1e-05
#  9:  6.0123e-01  6.0108e-01  5e-04  6e-04  8e-14  2e-06
# 10:  6.0136e-01  6.0130e-01  2e-04  2e-04  2e-13  5e-07
# 11:  6.0141e-01  6.0139e-01  8e-05  9e-05  3e-13  1e-07
# 12:  6.0144e-01  6.0143e-01  2e-05  2e-05  5e-13  3e-08
# 13:  6.0144e-01  6.0144e-01  5e-06  6e-06  8e-13  4e-09
# 14:  6.0145e-01  6.0145e-01  7e-07  9e-07  5e-12  2e-10
# 15:  6.0145e-01  6.0145e-01  2e-07  3e-07  1e-11  6e-11
# ...

# %%
n=1024

# %%
res11 = np.matmul(a5, np.array(x11[:n]))-b5
res22 = np.matmul(a5, np.array(x22[:n]))-b5
res33 = np.matmul(a5, np.array(x33[:n]))-b5

# %%
np.sum(np.abs(res11))
# Out:
# 575.9002508243587

# %%
np.sum(np.square(res22))
# Out:
# 350.2084591519642

# %%
np.max(np.abs(res33))
# Out:
# 0.6014457218550024

# %%
fig1, ax1 = plt.subplots()
ax1.hist(res11, bins=25)
ax1.set_xlabel('Residuals')
ax1.set_ylabel('Number')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Number')

# %%
fig2, ax2 = plt.subplots()
ax2.hist(res22, bins=25, color='red')
ax2.set_xlabel('Residuals')
ax2.set_ylabel('Number')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Number')

# %%
fig3, ax3 = plt.subplots()
ax3.hist(res33, bins=25, color='green')
ax3.set_xlabel('Residuals')
ax3.set_ylabel('Number')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Number')
